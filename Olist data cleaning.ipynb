# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np


olist_customers = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_customers_dataset.csv")

olist_customers.head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# ...

# %%
olist_customers.shape
# Out:
# (99441, 5)

# %%
olist_customers.dtypes
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %%
olist_order_items = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_order_items_dataset.csv")

olist_order_items.head(10)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5  00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6  00054e8431b9d7675808bcb819fb4a32              1
# 7  000576fe39319847cbb9d288c5617fa6              1
# 8  0005a1a1728c9d785b8e2b08b904576c              1
# 9  0005f50442cb953dcd1d21e1fb923495              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# ...

# %%
olist_order_items .shape
# Out:
# (112650, 7)

# %%
olist_order_items.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
olist_products = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_products_dataset.csv")

olist_products.head(10)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
# 5  41d3672d4792049fa1779bb35283ed13  instrumentos_musicais
# 6  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 7  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
# 8  37cc742be07708b53a98702e77a21a02       eletrodomesticos
# 9  8c92109888e8cdf9d66dc7e463025574             brinquedos
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# ...

# %%
olist_products.shape
# Out:
# (32951, 9)

# %%
olist_products_category = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\product_category_name_translation.csv")

olist_products_category.head(10)
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor
# 5           esporte_lazer                sports_leisure
# 6              perfumaria                     perfumery
# 7   utilidades_domesticas                    housewares
# 8               telefonia                     telephony
# 9      relogios_presentes                 watches_gifts

# %%
olist_products_category.shape
# Out:
# (71, 2)

# %%
olist_order = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_orders_dataset.csv")

olist_order.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...

# %%
olist_order.shape
# Out:
# (99441, 8)

# %%
olist_orders_reviews = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_order_reviews_dataset.csv")

olist_orders_reviews.head(10)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 5  15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6  07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# 7  7c6400515c67679fbee952a7525281ef  c31a859e34e3adac22f376954e19b39d
# 8  a3f6f7f6f433de0aefbb97da197c554c  9c214ac970e84273583ab523dfafd09b
# 9  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# ...

# %%
olist_orders_reviews.shape
# Out:
# (99224, 7)

# %%
olist_orders_payments = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_order_payments_dataset.csv")
olist_orders_payments.head(10)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 5  298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 6  771ee386b001f06208a7419e4fc1bbd7                   1  credit_card
# 7  3d7239c394a212faae122962df514ac7                   1  credit_card
# 8  1f78449c87a54faf9e96e88ba1491fa9                   1  credit_card
# 9  0573b5e23cbd798006520e1d5b4c6714                   1       boleto
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# ...

# %%
olist_orders_payments.shape
# Out:
# (103886, 5)

# %%
olist_sellers = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_sellers_dataset.csv")
olist_sellers.head(10)
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
# 5  c240c4061717ac1806ae6ee72be3533b                   20920
# 6  e49c26c3edfa46d227d5121a6b6e4d37                   55325
# 7  1b938a7ec6ac5061a66a3766e0e75f90                   16304
# 8  768a86e36ad6aae3d03ee3c6433d61df                    1529
# 9  ccc4bbb5f32a6ab2b7066a4130f114e3                   80310
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# 5     rio de janeiro           RJ
# 6             brejao           PE
# ...

# %%
olist_sellers.shape
# Out:
# (3095, 4)

# %%
olist_geoloc= pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_geolocation_dataset.csv")
olist_geoloc.head(10)
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
# 5                         1012       -23.547762       -46.635361
# 6                         1047       -23.546273       -46.641225
# 7                         1013       -23.546923       -46.634264
# 8                         1029       -23.543769       -46.634278
# 9                         1011       -23.547640       -46.636032
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP
# ...

# %%
olist_geoloc.shape
# Out:
# (1000163, 5)

# %%
                                                  #Cleaning customer table  (Data quality check for order table)
                                                                   # All data looks fine -- no need cleaning

olist_customers = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_customers_dataset.csv")

olist_customers.head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# ...

# %%
olist_customers.shape
# Out:
# (99441, 5)

# %%
olist_customers.dtypes
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %%
olist_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
olist_customers.isnull().sum()                                                   #Count missing values
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
olist_customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
olist_customers.nunique()
# Out:
# customer_id                 99441
# customer_unique_id          96096
# customer_zip_code_prefix    14994
# customer_city                4119
# customer_state                 27
# dtype: int64

# %%
olist_customers['customer_state'].unique()
# Out:
# array(['SP', 'SC', 'MG', 'PR', 'RJ', 'RS', 'PA', 'GO', 'ES', 'BA', 'MA',
#        'MS', 'CE', 'DF', 'RN', 'PE', 'MT', 'AM', 'AP', 'AL', 'RO', 'PB',
#        'TO', 'PI', 'AC', 'SE', 'RR'], dtype=object)

# %%
olist_customers.columns.tolist()                                         # Convert column names to a list
# Out:
# ['customer_id',
#  'customer_unique_id',
#  'customer_zip_code_prefix',
#  'customer_city',
#  'customer_state']

# %%
                                                          # Check for leading/trailing whitespace 

olist_customers["customer_state"].str.strip().eq(olist_customers["customer_state"]).all()
# Out:
# np.True_

# %%
                                                            # Check for empty strings

for col in ["customer_id", "customer_unique_id", "customer_city", "customer_state"]:
    print(col, (olist_customers[col] == "").sum())
# Out:
# customer_id 0
# customer_unique_id 0
# customer_city 0
# customer_state 0

# %%
                                                             # Data quality check for order table
olist_order = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_orders_dataset.csv")

olist_order.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...

# %%
olist_order.shape
# Out:
# (99441, 8)

# %%
olist_order.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
olist_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
olist_order.columns.tolist()
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date']

# %%
olist_order.duplicated().sum()
# Out:
# np.int64(0)

# %%
olist_order.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
                                                                   #changing data types for date column
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

for col in date_columns:
    olist_order[col] = pd.to_datetime(olist_order[col], errors="coerce")

# %%
olist_order["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
olist_order["order_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
olist_order["order_purchase_timestamp"].min()
# Out:
# Timestamp('2016-09-04 21:15:19')

# %%
olist_order["order_purchase_timestamp"].max()
# Out:
# Timestamp('2018-10-17 17:30:18')

# %%
olist_order["order_delivered_customer_date"].isnull().sum()
# Out:
# np.int64(2965)

# %%
olist_order["order_estimated_delivery_date"].isnull().sum()
# Out:
# np.int64(0)

# %%
olist_order[olist_order["order_delivered_customer_date"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# shipped        1107
# canceled        619
# unavailable     609
# invoiced        314
# processing      301
# delivered         8
# created           5
# approved          2
# Name: count, dtype: int64

# %%
olist_order[
    (olist_order["order_status"] == "delivered") &
    (olist_order["order_delivered_customer_date"].isnull())
]
# Out:
#                                order_id                       customer_id  \
# 3002   2d1e2d5bf4dc7227b3bfebb81328c15f  ec05a6d8558c6455f0cbbd8a420ad34f
# 20618  f5dd62b788049ad9fc0526e3ad11a097  5e89028e024b381dc84a13a3570decb4
# 43834  2ebdfc4f15f23b91474edf87475f108e  29f0540231702fda0cfdee0a310f11aa
# 79263  e69f75a717d64fc5ecdfae42b2e8e086  cfda40ca8dd0a5d486a9635b611b398a
# 82868  0d3268bad9b086af767785e3f0fc0133  4f1d63d35fb7c8999853b2699f5c7649
# 92643  2d858f451373b04fb5c984a1cc2defaf  e08caf668d499a6d643dafd7c5cc498a
# 97647  ab7c89dc1bf4a1ead9d6ec1ec8968a84  dd1b84a7286eb4524d52af4256c0ba24
# 98038  20edc82cf5400ce95e1afacc25798b31  28c37425f1127d887d7337f284080a0f
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 3002     delivered      2017-11-28 17:44:07 2017-11-28 17:56:40
# 20618    delivered      2018-06-20 06:58:43 2018-06-20 07:19:05
# 43834    delivered      2018-07-01 17:05:11 2018-07-01 17:15:12
# ...

# %%
                                                        # Data quality check for order items table

olist_order_items = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_order_items_dataset.csv")

olist_order_items.head(10)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5  00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6  00054e8431b9d7675808bcb819fb4a32              1
# 7  000576fe39319847cbb9d288c5617fa6              1
# 8  0005a1a1728c9d785b8e2b08b904576c              1
# 9  0005f50442cb953dcd1d21e1fb923495              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# ...

# %%
olist_order_items.shape
# Out:
# (112650, 7)

# %%
olist_order_items.dtypes
# Out:
# order_id                       object
# order_item_id                   int64
# product_id                     object
# seller_id                      object
# shipping_limit_date    datetime64[ns]
# price                         float64
# freight_value                 float64
# dtype: object

# %%
olist_order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
olist_order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
olist_order_items.duplicated(
    subset=["order_id", "order_item_id"]
).sum()
# Out:
# np.int64(0)

# %%
olist_order_items["price"].describe()
# Out:
# count    112650.000000
# mean        120.653739
# std         183.633928
# min           0.850000
# 25%          39.900000
# 50%          74.990000
# 75%         134.900000
# max        6735.000000
# Name: price, dtype: float64

# %%
(olist_order_items["freight_value"] < 0).sum()
# Out:
# np.int64(0)

# %%
olist_order_items["shipping_limit_date"] = pd.to_datetime(
    olist_order_items["shipping_limit_date"],
    errors="coerce"
)

# %%
olist_products = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_products_dataset.csv")

olist_products.head(10)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
# 5  41d3672d4792049fa1779bb35283ed13  instrumentos_musicais
# 6  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 7  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
# 8  37cc742be07708b53a98702e77a21a02       eletrodomesticos
# 9  8c92109888e8cdf9d66dc7e463025574             brinquedos
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# ...

# %%
olist_products.shape
# Out:
# (32951, 9)

# %%
olist_products.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
olist_products.duplicated().sum()
# Out:
# np.int64(0)

# %%
olist_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
olist_products[["product_id", "product_category_name"]].isnull().sum()
# Out:
# product_id               0
# product_category_name    0
# dtype: int64

# %%
missing_category = olist_products[
    olist_products["product_category_name"].isnull()
]

missing_category.merge(
    olist_order_items,
    on="product_id",
    how="inner"
).head(20)
# Out:
#                           product_id product_category_name  \
# 0   a41e356c76fab66334f36de622ecbd3a                   NaN
# 1   d8dee61c2034d6d075997acef1870e9b                   NaN
# 2   56139431d72cd51f19eb9f7dae4d1617                   NaN
# 3   46b48281eb6d663ced748f324108c733                   NaN
# 4   46b48281eb6d663ced748f324108c733                   NaN
# 5   46b48281eb6d663ced748f324108c733                   NaN
# 6   46b48281eb6d663ced748f324108c733                   NaN
# 7   46b48281eb6d663ced748f324108c733                   NaN
# 8   5fb61f482620cb672f5e586bb132eae9                   NaN
# 9   e10758160da97891c2fdcbc35f0f031d                   NaN
# 10  e10758160da97891c2fdcbc35f0f031d                   NaN
# 11  39e3b9b12cd0bf8ee681bbc1c130feb5                   NaN
# 12  39e3b9b12cd0bf8ee681bbc1c130feb5                   NaN
# 13  39e3b9b12cd0bf8ee681bbc1c130feb5                   NaN
# 14  794de06c32a626a5692ff50e4985d36f                   NaN
# ...

# %%
olist_products["product_category_name"] = (
    olist_products["product_category_name"]
    .fillna("Unknown")
)

# %%
olist_products["product_category_name"] = (
    olist_products["product_category_name"]
    .fillna("Unknown")
)

# %%
olist_products["product_category_name"].unique()
# Out:
# array(['perfumaria', 'artes', 'esporte_lazer', 'bebes',
#        'utilidades_domesticas', 'instrumentos_musicais', 'cool_stuff',
#        'moveis_decoracao', 'eletrodomesticos', 'brinquedos',
#        'cama_mesa_banho', 'construcao_ferramentas_seguranca',
#        'informatica_acessorios', 'beleza_saude', 'malas_acessorios',
#        'ferramentas_jardim', 'moveis_escritorio', 'automotivo',
#        'eletronicos', 'fashion_calcados', 'telefonia', 'papelaria',
#        'fashion_bolsas_e_acessorios', 'pcs', 'casa_construcao',
#        'relogios_presentes', 'construcao_ferramentas_construcao',
#        'pet_shop', 'eletroportateis', 'agro_industria_e_comercio',
#        'Unknown', 'moveis_sala', 'sinalizacao_e_seguranca',
#        'climatizacao', 'consoles_games', 'livros_interesse_geral',
#        'construcao_ferramentas_ferramentas',
#        'fashion_underwear_e_moda_praia', 'fashion_roupa_masculina',
#        'moveis_cozinha_area_de_servico_jantar_e_jardim',
# ...

# %%
olist_products["product_category_name"].nunique(dropna=False)
# Out:
# 74

# %%
                                                 # Compare Products vs. Translation table


set(olist_products["product_category_name"].dropna()) - set(olist_products_category["product_category_name"])
# Out:
# {'Unknown', 'pc_gamer', 'portateis_cozinha_e_preparadores_de_alimentos'}

# %%
                                                       # merge the translation table with the products table.

# %%
olist_products = olist_products.merge(
    olist_products_category,
    on="product_category_name",
    how="left"
)
olist_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
olist_products[[
    "product_category_name_english_x",
    "product_category_name_english_y"
]].isnull().sum()
# Out:
# product_category_name_english_x    623
# product_category_name_english_y    623
# dtype: int64

# %%
olist_products["product_category"] = (
    olist_products["product_category_name_english_y"]
    .fillna(olist_products["product_category_name"])
)

# %%
olist_products_clean = olist_products[
    ["product_id", "product_category"]
]
olist_products_clean.head()
# Out:
#                          product_id product_category
# 0  1e9e8ef04dbcff4541ed26657ea517e5        perfumery
# 1  3aa071139cb16b67ca9e5dea641aaa2f              art
# 2  96bd76ec8810374ed1b65e291975717f   sports_leisure
# 3  cef67bcfe19066a932b7673e239eb23d             baby
# 4  9dc1a7de274444849c219cff195d0b71       housewares

# %%
olist_products_clean['product_category'].unique()
# Out:
# array(['perfumery', 'art', 'sports_leisure', 'baby', 'housewares',
#        'musical_instruments', 'cool_stuff', 'furniture_decor',
#        'home_appliances', 'toys', 'bed_bath_table',
#        'construction_tools_safety', 'computers_accessories',
#        'health_beauty', 'luggage_accessories', 'garden_tools',
#        'office_furniture', 'auto', 'electronics', 'fashion_shoes',
#        'telephony', 'stationery', 'fashion_bags_accessories', 'computers',
#        'home_construction', 'watches_gifts',
#        'construction_tools_construction', 'pet_shop', 'small_appliances',
#        'agro_industry_and_commerce', 'Unknown', 'furniture_living_room',
#        'signaling_and_security', 'air_conditioning', 'consoles_games',
#        'books_general_interest', 'costruction_tools_tools',
#        'fashion_underwear_beach', 'fashion_male_clothing',
#        'kitchen_dining_laundry_garden_furniture',
#        'industry_commerce_and_business', 'fixed_telephony',
# ...

# %%
olist_products_clean["product_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
olist_products_clean.dtypes
# Out:
# product_id          object
# product_category    object
# dtype: object

# %%
olist_products_clean.to_excel(
    r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_products_clean.xlsx",
    index=False
)

# %%
olist_products_clean.shape
# Out:
# (32951, 2)

# %%
olist_customers_clean = olist_customers[
    ["customer_id",
     "customer_unique_id",
     "customer_city",
     "customer_state"]
]

olist_customers_clean.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#            customer_city customer_state
# 0                 franca             SP
# 1  sao bernardo do campo             SP
# 2              sao paulo             SP
# 3        mogi das cruzes             SP
# 4               campinas             SP

# %%
olist_customers_clean.to_csv(
    r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_customers_clean.csv",
    index=False
)

# %%
olist_products_clean.to_csv(
    r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_products_clean.csv",
    index=False
)

# %%
olist_order_items_clean = olist_order_items[
    [
        "order_id",
        "order_item_id",
        "product_id",
        "seller_id",
        "price",
        "freight_value"
    ]
]

# %%
olist_order_items_clean.dtypes
# Out:
# order_id          object
# order_item_id      int64
# product_id        object
# seller_id         object
# price            float64
# freight_value    float64
# dtype: object

# %%
olist_order_items_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   order_id       112650 non-null  object
#  1   order_item_id  112650 non-null  int64
#  2   product_id     112650 non-null  object
#  3   seller_id      112650 non-null  object
#  4   price          112650 non-null  float64
#  5   freight_value  112650 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 5.2+ MB

# %%
olist_order_items_clean.to_csv(
    r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_order_items_clean.csv",
    index=False
)

# %%
olist_orders_clean = olist_order[
    [
        "order_id",
        "customer_id",
        "order_status",
        "order_purchase_timestamp",
        "order_delivered_customer_date",
        "order_estimated_delivery_date"
    ]
]

# %%
olist_orders_clean.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
olist_orders_clean.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
olist_orders_clean.to_csv(
    r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_orders_clean.csv",
    index=False
)

# %%
                                                      # data quality check for orders reviews table

olist_orders_reviews = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_order_reviews_dataset.csv")

olist_orders_reviews.head(10)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 5  15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6  07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# 7  7c6400515c67679fbee952a7525281ef  c31a859e34e3adac22f376954e19b39d
# 8  a3f6f7f6f433de0aefbb97da197c554c  9c214ac970e84273583ab523dfafd09b
# 9  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# ...

# %%
olist_orders_reviews.dtypes
# Out:
# review_id                  object
# order_id                   object
# review_score                int64
# review_comment_title       object
# review_comment_message     object
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object

# %%
olist_orders_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
olist_orders_reviews.duplicated().sum()
# Out:
# np.int64(0)

# %%
olist_orders_reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
olist_orders_reviews.shape
# Out:
# (99224, 7)

# %%
olist_reviews_clean = olist_orders_reviews[
    [
        "order_id",
        "review_score",
        "review_creation_date"
    ]
].copy()

# %%
olist_reviews_clean.dtypes
# Out:
# order_id                        object
# review_score                     int64
# review_creation_date    datetime64[ns]
# dtype: object

# %%
olist_reviews_clean["review_creation_date"] = pd.to_datetime(
    olist_reviews_clean["review_creation_date"]
)

# %%
olist_reviews_clean.isnull().sum()
# Out:
# order_id                0
# review_score            0
# review_creation_date    0
# dtype: int64

# %%
olist_reviews_clean['review_score'].unique()
# Out:
# array([4, 5, 1, 3, 2])

# %%
olist_reviews_clean.shape
# Out:
# (99224, 3)

# %%
olist_reviews_clean.to_csv(
    r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_reviews_clean.csv",
    index=False
)

# %%
                                    # data quality check for seller table

olist_sellers = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_sellers_dataset.csv")
olist_sellers.head(10)
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
# 5  c240c4061717ac1806ae6ee72be3533b                   20920
# 6  e49c26c3edfa46d227d5121a6b6e4d37                   55325
# 7  1b938a7ec6ac5061a66a3766e0e75f90                   16304
# 8  768a86e36ad6aae3d03ee3c6433d61df                    1529
# 9  ccc4bbb5f32a6ab2b7066a4130f114e3                   80310
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# 5     rio de janeiro           RJ
# 6             brejao           PE
# ...

# %%
olist_sellers.shape
# Out:
# (3095, 4)

# %%
olist_sellers.dtypes
# Out:
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object

# %%
olist_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
olist_sellers.duplicated().sum()
# Out:
# np.int64(0)

# %%
olist_sellers_clean = olist_sellers[
    [
        "seller_id",
        "seller_city",
        "seller_state"
    ]
].copy()

# %%
olist_sellers_clean.to_csv(
    r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_sellers_clean.csv",
    index=False
)

# %%
                                  # data quality check for orders payment table

olist_orders_payments = pd.read_csv(r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_order_payments_dataset.csv")
olist_orders_payments.head(10)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 5  298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 6  771ee386b001f06208a7419e4fc1bbd7                   1  credit_card
# 7  3d7239c394a212faae122962df514ac7                   1  credit_card
# 8  1f78449c87a54faf9e96e88ba1491fa9                   1  credit_card
# 9  0573b5e23cbd798006520e1d5b4c6714                   1       boleto
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# ...

# %%
olist_orders_payments.shape
# Out:
# (103886, 5)

# %%
olist_orders_payments.dtypes
# Out:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
olist_orders_payments.duplicated().sum()
# Out:
# np.int64(0)

# %%
olist_orders_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
olist_orders_payments['payment_type'].unique()
# Out:
# array(['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined'],
#       dtype=object)

# %%
olist_payments_clean = olist_orders_payments[
    [
        "order_id",
        "payment_type",
        "payment_installments",
        "payment_value"
    ]
].copy()

# %%
olist_payments_clean.isnull().sum()
# Out:
# order_id                0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
olist_payments_clean.to_csv(
    r"C:\Users\SEKAR\Desktop\Raw data\Olist E-commerce\olist_payments_clean.csv",
    index=False
)

# %%
olist_payments_clean.columns.tolist()
# Out:
# ['order_id', 'payment_type', 'payment_installments', 'payment_value']

# %%
olist_sellers_clean.columns.tolist()
# Out:
# ['seller_id', 'seller_city', 'seller_state']

# %%
olist_reviews_clean.columns.tolist()
# Out:
# ['order_id', 'review_score', 'review_creation_date']
